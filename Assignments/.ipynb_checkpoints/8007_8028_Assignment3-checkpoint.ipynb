# %% [markdown]
# ### Name: Ashish Mulani
# ### PRN: 260240128007
# ------------------------------
# ### Name: Pranita Lad
# ### PRN: 260240128028

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer, make_column_selector
from sklearn.ensemble import BaggingRegressor, StackingRegressor
from xgboost import XGBRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression, ElasticNet, Ridge
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, 
from sklearn.pipeline import Pipeline
from sklearn.model_selection import KFold, GridSearchCV
from tqdm.notebook import tqdm
import joblib
from contextlib import contextmanager
import os
os.chdir("D:/AllDatasets/PredictingRoadAccident")

# %%
# Generated using AI to check progress
import joblib
from contextlib import contextmanager

@contextmanager
def tqdm_joblib(tqdm_object):
    """Context manager to patch joblib to report into tqdm progress bar"""
    class TqdmBatchCompletionCallback(joblib.parallel.BatchCompletionCallBack):
        def __call__(self, *args, **kwargs):
            tqdm_object.update(n=self.batch_size)
            return super().__call__(*args, **kwargs)

    old_batch_callback = joblib.parallel.BatchCompletionCallBack
    joblib.parallel.BatchCompletionCallBack = TqdmBatchCompletionCallback
    try:
        yield tqdm_object
    finally:
        joblib.parallel.BatchCompletionCallBack = old_batch_callback
        tqdm_object.close()

# %%
train = pd.read_csv('train.csv',index_col=0)
test = pd.read_csv('test.csv',index_col=0)
train
# Out:
#        road_type  num_lanes  curvature  speed_limit  lighting weather  \
# id
# 0          urban          2       0.06           35  daylight   rainy
# 1          urban          4       0.99           35  daylight   clear
# 2          rural          4       0.63           70       dim   clear
# 3        highway          4       0.07           35       dim   rainy
# 4          rural          1       0.58           60  daylight   foggy
# ...          ...        ...        ...          ...       ...     ...
# 517749   highway          4       0.10           70  daylight   foggy
# 517750     rural          4       0.47           35  daylight   rainy
# 517751     urban          4       0.62           25  daylight   foggy
# 517752   highway          3       0.63           25     night   clear
# 517753   highway          2       0.31           45       dim   rainy
#
#         road_signs_present  public_road time_of_day  holiday  school_season  \
# id
# ...

# %%
ohe = OneHotEncoder(sparse_output=False, drop='first').set_output(transform='pandas')
transf = ColumnTransformer(transformers=[('OHE', 
       ohe, make_column_selector(dtype_include=object) )] ,
    remainder='passthrough',verbose_feature_names_out=False).set_output(transform='pandas')

# %%
X, y = train.drop('accident_risk', axis=1), train['accident_risk']
kfold = KFold(n_splits=5, shuffle=True, random_state=26)

# %%
lr = LinearRegression()
el = ElasticNet()
knn = KNeighborsRegressor()
dtr = DecisionTreeRegressor(random_state=26)
rf = RandomForestRegressor(n_estimators=50, random_state=26)
xgbm = XGBRegressor(random_state=26)

# %% [markdown]
# ## Bagging

# %%
total_fits = 5 * (3 * 3)
bagg = BaggingRegressor(random_state=26, n_jobs=-1)

pipe_bagg = Pipeline([('OHE', transf), ('BAGG', bagg)])

params = {'BAGG__estimator': [lr, el, dtr], 'BAGG__n_estimators': [10, 15, 50]}

gcv_bagg = GridSearchCV(pipe_bagg, param_grid=params, cv=kfold, scoring='r2', 
                        n_jobs=-1, verbose=1)
with tqdm_joblib(tqdm(total=total_fits, desc="Bagging Progress")) as progress_bar:
    gcv_bagg.fit(X, y)

print(f"\nBest R² Score (Bagging) : {gcv_bagg.best_score_:.4f}")
print(f"Best Params          : {gcv_bagg.best_params_}")
# Out:
# Bagging Progress:   0%|          | 0/45 [00:00<?, ?it/s]
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
#
# Best R² Score (Bagging) : 0.8709
# Best Params          : {'BAGG__estimator': DecisionTreeRegressor(random_state=26), 'BAGG__n_estimators': 50}

# %%
df_bagg = pd.DataFrame(gcv_bagg.cv_results_)
df_bagg[['param_BAGG__estimator', 'param_BAGG__n_estimators', 'mean_test_score']]
df_bagg.sort_values('mean_test_score', ascending=False)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 8      80.575265      7.356762         1.248079        0.340712
# 7      51.489821      0.667255         4.128263        0.277707
# 6      45.371743      3.112893         4.595968        0.561916
# 2      54.747647      2.056474         5.124865        0.141644
# 1      14.478192      0.270644         0.957444        0.093193
# 0      11.249853      0.196838         0.736232        0.080699
# 5      13.600863      0.907276         3.567207        0.376818
# 4       6.226071      0.248478         1.173223        0.654650
# 3       5.023985      1.082643         1.325090        0.294311
#
#                     param_BAGG__estimator  param_BAGG__n_estimators  \
# 8  DecisionTreeRegressor(random_state=26)                        50
# 7  DecisionTreeRegressor(random_state=26)                        15
# 6  DecisionTreeRegressor(random_state=26)                        10
# ...

# %%
y_pred_bagg = gcv_bagg.best_estimator_.predict(test)
y_pred_bagg = np.clip(y_pred_bagg, 0, None)  # accident_risk cannot be negative

sample_sub = pd.read_csv('sample_submission.csv')
sub_bagg = sample_sub.copy()
sub_bagg['accident_risk'] = y_pred_bagg
sub_bagg.to_csv('submission_bagging.csv', index=False)
sub_bagg.head()
# Out:
#        id  accident_risk
# 0  517754         0.3384
# 1  517755         0.1312
# 2  517756         0.1606
# 3  517757         0.3136
# 4  517758         0.3964

# %% [markdown]
# ## Stacking

# %%
from sklearn.ensemble import HistGradientBoostingRegressor

# %%
stack = StackingRegressor(estimators=[('LR', lr), ('EL', el), ('DTR', dtr),('RF',rf)],
                           final_estimator= HistGradientBoostingRegressor, passthrough=True, cv=3, n_jobs=-1)

pipe_stack = Pipeline([('OHE', transf), ('STACK', stack)])

params_stack = {
    'STACK__final_estimator': [Ridge(alpha=1.0), HistGradientBoostingRegressor(random_state=26, max_iter=50)]
}

gcv_stack = GridSearchCV(pipe_stack, param_grid=params_stack, cv=kfold, scoring='r2', n_jobs=-1)

total_fits_stack = kfold.get_n_splits() * len(params_stack['STACK__final_estimator'])
with tqdm_joblib(tqdm(total=total_fits, desc="Stacking Progress")) as progress_bar:
    gcv_stack.fit(X, y)

print(f"\nBest CV R² (Stacking) : {gcv_stack.best_score_:.4f}")
print(f"Best Params     : {gcv_stack.best_params_}")
# Out:
# Stacking Progress:   0%|          | 0/45 [00:00<?, ?it/s]
# Best CV R² (Stacking) : 0.8802
# Best Params     : {'STACK__final_estimator': HistGradientBoostingRegressor(max_iter=50, random_state=26)}

# %%
df_stack = pd.DataFrame(gcv_stack.cv_results_)

df_stack[['param_STACK__final_estimator', 'mean_test_score', 'std_test_score']]
df_stack.sort_values('mean_test_score', ascending=False)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 1     465.141595      2.365679         5.251015        0.297765
# 0     456.279969      5.905028         5.015943        0.285456
#
#                         param_STACK__final_estimator  \
# 1  HistGradientBoostingRegressor(max_iter=50, ran...
# 0                                            Ridge()
#
#                                               params  split0_test_score  \
# 1  {'STACK__final_estimator': HistGradientBoostin...           0.880136
# 0                {'STACK__final_estimator': Ridge()}           0.873643
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 1           0.878977           0.881317           0.880329           0.880380
# 0           0.872660           0.874876           0.873615           0.873882
#
#    mean_test_score  std_test_score  rank_test_score
# 1         0.880228        0.000747                1
# ...

# %%
y_pred_stack = gcv_stack.best_estimator_.predict(test)
y_pred_stack = np.clip(y_pred_stack, 0, None)

sub_stack = sample_sub.copy()
sub_stack['accident_risk'] = y_pred_stack
sub_stack.to_csv('submission_stacking.csv', index=False)
sub_stack.head()
# Out:
#        id  accident_risk
# 0  517754       0.327373
# 1  517755       0.125839
# 2  517756       0.175351
# 3  517757       0.337094
# 4  517758       0.393910

# %% [markdown]
# ## Boosting

# %%
# --- Gradient Boosting ---
gbm = GradientBoostingRegressor(random_state=26)
pipe_gbm = Pipeline([('OHE', transf), ('GBM', gbm)])

params_gbm = {
    'GBM__n_estimators'  : [50, 100],
    'GBM__learning_rate' : [0.1, 0.2],
    'GBM__max_depth'     : [3, 4]
}

gcv_gbm = GridSearchCV(
    pipe_gbm, param_grid=params_gbm,
    cv=kfold, scoring='r2', n_jobs=-1, verbose=1
)
with tqdm_joblib(tqdm(total=60, desc="GBM Progress")) as progress_bar:
    gcv_gbm.fit(X, y)

print(f"\nBest CV R² (GBM)  : {gcv_gbm.best_score_:.4f}")
print(f"Best Params       : {gcv_gbm.best_params_}")
# Out:
# GBM Progress:   0%|          | 0/60 [00:00<?, ?it/s]
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
#
# Best CV R² (GBM)  : 0.8849
# Best Params       : {'GBM__learning_rate': 0.2, 'GBM__max_depth': 4, 'GBM__n_estimators': 100}

# %%
# --- XGBoost ---
xgb = XGBRegressor(random_state=26, verbosity=0, n_jobs=-1)
pipe_xgb = Pipeline([('OHE', transf), ('XGB', xgb)])

params_xgb = {
    'XGB__n_estimators'  : [50, 100],
    'XGB__learning_rate' : [0.05, 0.1, 0.2],
    'XGB__max_depth'     : [3, 4, 6]
}

gcv_xgb = GridSearchCV(
    pipe_xgb, param_grid=params_xgb,
    cv=kfold, scoring='r2', n_jobs=-1, verbose=1
)
with tqdm_joblib(tqdm(total=90, desc="XGBoost Progress")) as progress_bar:
    gcv_xgb.fit(X, y)

print(f"\nBest CV R² (XGBoost) : {gcv_xgb.best_score_:.4f}")
print(f"Best Params          : {gcv_xgb.best_params_}")
# Out:
# XGBoost Progress:   0%|          | 0/90 [00:00<?, ?it/s]
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
#
# Best CV R² (XGBoost) : 0.8861
# Best Params          : {'XGB__learning_rate': 0.2, 'XGB__max_depth': 6, 'XGB__n_estimators': 100}

# %%
# Pick the better boosting model
if gcv_gbm.best_score_ >= gcv_xgb.best_score_:
    best_boost = gcv_gbm
    boost_name = 'GradientBoosting'
else:
    best_boost = gcv_xgb
    boost_name = 'XGBoost'

print(f"Selected Boosting model: {boost_name}  (R²={best_boost.best_score_:.4f})")
# Out:
# Selected Boosting model: XGBoost  (R²=0.8861)

# %%
y_pred_boost = best_boost.best_estimator_.predict(test)
y_pred_boost = np.clip(y_pred_boost, 0, None)

sub_boost = sample_sub.copy()
sub_boost['accident_risk'] = y_pred_boost
sub_boost.to_csv('submission_boosting.csv', index=False)
sub_boost.head()
# Out:
#        id  accident_risk
# 0  517754       0.289152
# 1  517755       0.119326
# 2  517756       0.191567
# 3  517757       0.313115
# 4  517758       0.407953

# %% [markdown]
# ### After uploading on Kaggle the file with XGBoost got an score of 0.05598 which is best among all.
