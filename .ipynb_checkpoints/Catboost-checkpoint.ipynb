# %%
import lightgbm
lightgbm.__version__
# Out:
# '4.6.0'

# %%
from lightgbm import LGBMClassifier

# %%
gbm = LGBMClassifier()
gbm.fit(X_)

# %%
pip install catboost
# Out:
# ...
#   Using cached catboost-1.2.10-cp314-cp314-win_amd64.whl.metadata (1.5 kB)
# ...
#   Using cached graphviz-0.21-py3-none-any.whl.metadata (12 kB)
# ...
#    ---------------------------------------- 0.0/101.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/101.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/101.7 MB ? eta -:--:--
#    ---------------------------------------- 0.3/101.7 MB ? eta -:--:--
#    ---------------------------------------- 0.3/101.7 MB ? eta -:--:--
#    ---------------------------------------- 0.3/101.7 MB ? eta -:--:--
#    ---------------------------------------- 0.3/101.7 MB ? eta -:--:--
#    ---------------------------------------- 0.3/101.7 MB ? eta -:--:--
#    ---------------------------------------- 0.3/101.7 MB ? eta -:--:--
#    ---------------------------------------- 0.5/101.7 MB 201.0 kB/s eta 0:08:24
#    ---------------------------------------- 0.5/101.7 MB 201.0 kB/s eta 0:08:24
# ...
