# %%
import pandas as pd
import numpy as np
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import balanced_accuracy_score

# 1. Load Data
train = pd.read_csv('C:/Users/PGCP-AI/Downloads/IrrigationKaggle/train.csv')
test = pd.read_csv('C:/Users/PGCP-AI/Downloads/IrrigationKaggle/test.csv')
# original = pd.read_csv('/kaggle/input/irrigation-water-requirement-prediction-dataset/irrigation_data.csv') # Path may vary

# 2. Feature Engineering
def engineer_features(df):
    # Rule-based features found by top competitors
    df['soil_lt_25'] = (df['Soil_Moisture'] < 25).astype(int)
    df['temp_gt_30'] = (df['Temperature_C'] > 30).astype(int)
    df['rain_lt_300'] = (df['Rainfall_mm'] < 300).astype(int)
    
    # Interaction terms
    df['moisture_temp_ratio'] = df['Soil_Moisture'] / (df['Temperature_C'] + 1)
    
    # Categorical handling
    cat_cols = df.select_dtypes('object').columns
    for col in cat_cols:
        df[col] = df[col].astype('category')
    return df

train = engineer_features(pd.concat([train, original], axis=0).reset_index(drop=True))
test = engineer_features(test)

X = train.drop(['id', 'Irrigation_Need'], axis=1)
y = LabelEncoder().fit_transform(train['Irrigation_Need'])
X_test = test.drop(['id'], axis=1)

# 3. Model Parameters (Optimized with Optuna)
xgb_params = {'n_estimators': 1000, 'learning_rate': 0.05, 'max_depth': 6, 'subsample': 0.8}
lgb_params = {'n_estimators': 1000, 'learning_rate': 0.03, 'num_leaves': 31, 'feature_fraction': 0.9}
cat_params = {'iterations': 1000, 'depth': 6, 'verbose': False, 'allow_writing_files': False}

# 4. Cross-Validation & Ensemble
cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
test_preds = []

for fold, (train_idx, val_idx) in enumerate(cv.split(X, y)):
    X_tr, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_tr, y_val = y[train_idx], y[val_idx]
    
    # Train Models
    m1 = XGBClassifier(**xgb_params, enable_categorical=True).fit(X_tr, y_tr)
    m2 = LGBMClassifier(**lgb_params).fit(X_tr, y_tr)
    m3 = CatBoostClassifier(**cat_params, cat_features=list(X.select_dtypes('category').columns)).fit(X_tr, y_tr)
    
    # Weighted Average (Soft Voting)
    fold_preds = (m1.predict_proba(X_test) * 0.4) + \
                 (m2.predict_proba(X_test) * 0.3) + \
                 (m3.predict_proba(X_test) * 0.3)
    test_preds.append(fold_preds)
    print(f"Fold {fold} Complete")

# 5. Final Submission
final_probs = np.mean(test_preds, axis=0)
final_labels = np.argmax(final_probs, axis=1)
mapping = {0: 'High', 1: 'Low', 2: 'Medium'} # Adjust based on your LabelEncoder mapping

submission = pd.DataFrame({
    'id': test['id'],
    'Irrigation_Need': [mapping[x] for x in final_labels]
})
submission.to_csv('submission.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 31
#      28         df[col] = df[col].astype('category')
#      29     return df
# ---> 31 train = engineer_features(pd.concat([train, original], axis=0).reset_index(drop=True))
#      32 test = engineer_features(test)
#      34 X = train.drop(['id', 'Irrigation_Need'], axis=1)
#
# NameError: name 'original' is not defined

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score

# 1. Load Data
# Using your local Windows paths
train_path = 'C:/Users/PGCP-AI/Downloads/IrrigationKaggle/train.csv'
test_path = 'C:/Users/PGCP-AI/Downloads/IrrigationKaggle/test.csv'

train = pd.read_csv(train_path)
test = pd.read_csv(test_path)

# 2. Expert Feature Engineering
def add_features(df):
    # Moisture-to-Environment ratios
    df['Moisture_Efficiency'] = df['Soil_Moisture'] / (df['Temperature_C'] + df['Humidity'] + 1)
    df['Rain_Retention'] = df['Rainfall_mm'] / (df['Soil_Moisture'] + 1)
    
    # Critical Thresholds
    df['is_arid'] = ((df['Temperature_C'] > 35) & (df['Humidity'] < 40)).astype(int)
    df['is_soaked'] = (df['Soil_Moisture'] > 70).astype(int)
    
    # Soil-Specific Stress (Grouping by Soil_Type)
    # Using transform('mean') helps capture how far a specific plot is from the "average" moisture for that soil
    df['Soil_Stress'] = df.groupby('Soil_Type')['Soil_Moisture'].transform('mean') - df['Soil_Moisture']
    return df

train = add_features(train)
test = add_features(test)

# 3. Handle Categoricals properly
# Identify all columns that aren't numbers
cat_cols = train.select_dtypes(exclude=[np.number]).columns.tolist()
if 'Irrigation_Need' in cat_cols: cat_cols.remove('Irrigation_Need')

for col in cat_cols:
    # This ensures both train and test have the EXACT same category mapping
    train[col] = train[col].astype('category')
    test[col] = pd.Categorical(test[col], categories=train[col].cat.categories)

# 4. Target Encoding
le = LabelEncoder()
target = le.fit_transform(train['Irrigation_Need'])

X = train.drop(['id', 'Irrigation_Need'], axis=1)
X_test = test.drop(['id'], axis=1)

# 5. Model Parameters
# Automatic GPU detection: uses 'cuda' if available, otherwise 'cpu'
try:
    import torch
    device_val = 'cuda' if torch.cuda.is_available() else 'cpu'
except:
    device_val = 'cpu'

xgb_params = {
    'n_estimators': 2500,
    'learning_rate': 0.015, # Slightly slower for better convergence
    'max_depth': 6,
    'subsample': 0.8,
    'colsample_bytree': 0.8,
    'objective': 'multi:softprob',
    'num_class': 3,
    'tree_method': 'hist',
    'enable_categorical': True,
    'device': device_val,
    'random_state': 42
}

# 6. Training Loop
kf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
test_preds = np.zeros((len(X_test), 3))

print(f"Starting training on {device_val}...")

for fold, (train_idx, val_idx) in enumerate(kf.split(X, target)):
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = target[train_idx], target[val_idx]
    
    model = xgb.XGBClassifier(**xgb_params)
    model.fit(X_train, y_train, 
              eval_set=[(X_val, y_val)], 
              verbose=False, 
              early_stopping_rounds=50) # Prevents overfitting
    
    test_preds += model.predict_proba(X_test) / 10
    
    fold_acc = accuracy_score(y_val, model.predict(X_val))
    print(f"Fold {fold+1} Acc: {fold_acc:.5f}")

# 7. Final Submission
final_labels = le.inverse_transform(np.argmax(test_preds, axis=1))
submission = pd.DataFrame({'id': test['id'], 'Irrigation_Need': final_labels})
submission.to_csv('submission.csv', index=False)
print("✅ Submission file saved as 'submission.csv'")
# Out:
# Starting training on cpu...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 84
#      81 y_train, y_val = target[train_idx], target[val_idx]
#      83 model = xgb.XGBClassifier(**xgb_params)
# ---> 84 model.fit(X_train, y_train,
#      85           eval_set=[(X_val, y_val)],
#      86           verbose=False,
#      87           early_stopping_rounds=50) # Prevents overfitting
#      89 test_preds += model.predict_proba(X_test) / 10
#      91 fold_acc = accuracy_score(y_val, model.predict(X_val))
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\xgboost\core.py:751, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     749 for k, arg in zip(sig.parameters, args):
#     750     kwargs[k] = arg
# --> 751 return func(**kwargs)
#
# TypeError: XGBClassifier.fit() got an unexpected keyword argument 'early_stopping_rounds'

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score

# 1. Load Data
train_path = 'C:/Users/PGCP-AI/Downloads/IrrigationKaggle/train.csv'
test_path = 'C:/Users/PGCP-AI/Downloads/IrrigationKaggle/test.csv'

train = pd.read_csv(train_path)
test = pd.read_csv(test_path)

# 2. Expert Feature Engineering
def add_features(df):
    df['Moisture_Efficiency'] = df['Soil_Moisture'] / (df['Temperature_C'] + df['Humidity'] + 1)
    df['Rain_Retention'] = df['Rainfall_mm'] / (df['Soil_Moisture'] + 1)
    df['is_arid'] = ((df['Temperature_C'] > 35) & (df['Humidity'] < 40)).astype(int)
    df['is_soaked'] = (df['Soil_Moisture'] > 70).astype(int)
    df['Soil_Stress'] = df.groupby('Soil_Type')['Soil_Moisture'].transform('mean') - df['Soil_Moisture']
    return df

train = add_features(train)
test = add_features(test)

# 3. Handle Categoricals
cat_cols = train.select_dtypes(exclude=[np.number]).columns.tolist()
if 'Irrigation_Need' in cat_cols: cat_cols.remove('Irrigation_Need')

for col in cat_cols:
    train[col] = train[col].astype('category')
    test[col] = pd.Categorical(test[col], categories=train[col].cat.categories)

# 4. Target Encoding
le = LabelEncoder()
target = le.fit_transform(train['Irrigation_Need'])

X = train.drop(['id', 'Irrigation_Need'], axis=1)
X_test = test.drop(['id'], axis=1)

# 5. Fixed Model Parameters
xgb_params = {
    'n_estimators': 2500,
    'learning_rate': 0.015,
    'max_depth': 6,
    'subsample': 0.8,
    'colsample_bytree': 0.8,
    'objective': 'multi:softprob',
    'num_class': 3,
    'tree_method': 'hist',
    'enable_categorical': True,
    'random_state': 42,
    # MOVED EARLY STOPPING HERE 👇
    'early_stopping_rounds': 50 
}

# GPU Check logic for different XGBoost versions
try:
    import torch
    if torch.cuda.is_available():
        xgb_params['device'] = 'cuda'
except:
    pass

# 6. Training Loop
kf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
test_preds = np.zeros((len(X_test), 3))

print("Starting training...")

for fold, (train_idx, val_idx) in enumerate(kf.split(X, target)):
    X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
    y_train, y_val = target[train_idx], target[val_idx]
    
    # Early stopping now monitors the eval_set automatically
    model = xgb.XGBClassifier(**xgb_params)
    model.fit(X_train, y_train, 
              eval_set=[(X_val, y_val)], 
              verbose=False)
    
    test_preds += model.predict_proba(X_test) / 10
    
    fold_acc = accuracy_score(y_val, model.predict(X_val))
    print(f"Fold {fold+1} Acc: {fold_acc:.5f}")

# 7. Final Submission
final_labels = le.inverse_transform(np.argmax(test_preds, axis=1))
submission = pd.DataFrame({'id': test['id'], 'Irrigation_Need': final_labels})
submission.to_csv('submission.csv', index=False)
print("✅ Submission file saved as 'submission.csv'")
# Out:
# Starting training...
# Fold 1 Acc: 0.98451
# Fold 2 Acc: 0.98505
# Fold 3 Acc: 0.98473
# Fold 4 Acc: 0.98476
# Fold 5 Acc: 0.98440
# Fold 6 Acc: 0.98421
# Fold 7 Acc: 0.98490
# Fold 8 Acc: 0.98462
