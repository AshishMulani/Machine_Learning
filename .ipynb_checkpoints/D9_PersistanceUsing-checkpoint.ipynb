# %%
import pickle 
import pandas as pd
import numpy as np

# %%
tst=pd.read_csv("Cases/Wisconsin/tst_cancer.csv")
tst
# Out:
#    Code  Clump  UniCell_Size  Uni_CellShape  MargAdh  SEpith  BareN  \
# 0  3444      5             4              3        1       3      2
# 1  3445      9             1              2        6       7      2
# 2  3446      9             4              8        2       2      4
# 3  3447      5            10             10       10       8      7
# 4  3448      1            10              1        1       2      5
# 5  3449      7             6              4        5       3      9
#
#    BChromatin  NoemN  Mitoses
# 0           2      3       10
# 1           7      7        2
# 2           6      1        1
# 3           1     10        7
# 4           5      1        1
# 5           1      1        2

# %%
infile=open('bestModel_breastCancer.pkl','rb')
objload=pickle.load(infile)
infile.close()

# %%
objload.predict(tst)
# Out:
# array(['Benign', 'Malignant', 'Malignant', 'Malignant', 'Benign',
#        'Malignant'], dtype=object)
